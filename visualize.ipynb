# %%
from Dijkstra import shortest_path
from build_network import build_graph
import csv
import gmaps
origin, dest = 'taxi_186', 'taxi_205'
print('building the graph')
graph = build_graph()
print('running dijkstra')
length, route, route_type = shortest_path(graph, origin, dest)
print(length)
print(route)
print(route_type)
# Out:
# building the graph
# running dijkstra
# [80.0, 147.0, 655.0, 1200.0, 480.0, 572.0]
# 3134.0
# ['taxi_186', 'bike_379', 'bike_490', 'lirr_1_8', 'lirr_1_15', 'lirr_1_83', 'taxi_205']
# ['walk', 'bike', 'walk', 'lirr 1', 'lirr 1', 'walk']

# %%
lines = []
colors = []
locations = []
subway,bus,lirr,taxi,bike = {},{},{},{},{}
with open('data/subway_gtfs/stops.txt') as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        subway[row[0]] = (float(row[4]),float(row[5]))
with open('data/lirr_gtfs/stops.txt') as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        lirr[row[0]] = (float(row[3]),float(row[4]))
for zone in ['Manhattan','Bronx','Brooklyn','Staten','Queens','NYC','mnr']:
    with open('data/bus_gtfs/'+zone+'_stops.txt') as f:
        reader = csv.reader(f)
        next(reader)
        for row in reader:
            bus[row[0]] = (float(row[2]),float(row[3])) if zone=='Staten' else (float(row[3]),float(row[4]))
with open('data/zone_latlon.csv') as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        taxi[row[0]] = (float(row[1]),float(row[2]))
with open('data/bikeStation_coordinates.csv') as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        bike[row[0]] = (float(row[1]),float(row[2]))

for loc in route:
    p = loc.split('_')
    if p[0]=='taxi': 
        locations.append(taxi[p[1]])
    elif p[0]=='bus':
        locations.append(bus[p[2]])
    elif p[0]=='subway':
        locations.append(subway[p[2]])
    elif p[0]=='lirr':
        locations.append(lirr[p[2]])
    elif p[0]=='bike':
        locations.append(bike[p[1]])
color_code = {'red':(255,0,0),'grey':(133, 146, 158),'brown':(160,82,45),
              'green':(0,128,0),'blue':(0,0,255),'violet':(148,0,211)}
for t in route_type:
    p = t.split(' ')
    if p[0]=='taxi': 
        colors.append(color_code['red'])
    elif p[0]=='bus':
        colors.append(color_code['green'])
    elif p[0]=='subway':
        colors.append(color_code['blue'])
    elif p[0]=='lirr':
        colors.append(color_code['violet'])
    elif p[0]=='bike':
        colors.append(color_code['grey'])
    elif p[0]=='walk':
        colors.append(color_code['brown'])
    else:
        colors.append((0,0,0))
for i in range(len(locations)-1):
    lines.append(gmaps.Line(locations[i],locations[i+1], 
                            stroke_weight=3.0,stroke_color=colors[i]))
gmaps.configure(api_key="AIzaSyBBtnqDUIJ39Y_hzdpWdP-PEXRTEFSSBes")
new_york_coordinates = (40.75, -74.00)
fig = gmaps.figure(center=new_york_coordinates, zoom_level=12)
drawing = gmaps.drawing_layer(features=lines)
fig.add_layer(drawing)
symbols = gmaps.symbol_layer(locations, fill_color=(0,0,0), stroke_color=(0,0,0))
fig.add_layer(symbols)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
print(taxi[origin[5:]],taxi[dest[5:]])
# Out:
# (40.74849718, -73.99243754) (40.69120145, -73.76314613)

# %%
graph.edges['taxi_236']
# Out:
# ['taxi_1',
#  'taxi_4',
#  'taxi_7',
#  'taxi_12',
#  'taxi_13',
#  'taxi_16',
#  'taxi_17',
#  'taxi_20',
#  'taxi_24',
#  'taxi_25',
#  'taxi_26',
#  'taxi_28',
#  'taxi_29',
#  'taxi_31',
#  'taxi_32',
#  'taxi_33',
#  'taxi_36',
#  'taxi_37',
#  'taxi_39',
#  'taxi_40',
#  'taxi_41',
#  'taxi_42',
#  'taxi_43',
#  'taxi_45',
#  'taxi_47',
#  'taxi_48',
#  'taxi_49',
#  'taxi_50',
#  'taxi_51',
#  'taxi_52',
#  'taxi_55',
#  'taxi_56',
#  'taxi_60',
#  'taxi_61',
#  'taxi_62',
#  'taxi_65',
#  'taxi_66',
#  'taxi_68',
#  'taxi_69',
#  'taxi_70',
#  'taxi_74',
#  'taxi_75',
#  'taxi_78',
#  'taxi_79',
#  'taxi_80',
#  'taxi_81',
#  'taxi_82',
#  'taxi_83',
#  'taxi_85',
#  'taxi_87',
#  'taxi_88',
#  'taxi_89',
#  'taxi_90',
#  'taxi_92',
#  'taxi_93',
#  'taxi_95',
#  'taxi_97',
#  'taxi_100',
#  'taxi_102',
#  'taxi_106',
#  'taxi_107',
#  'taxi_112',
#  'taxi_113',
#  'taxi_114',
#  'taxi_116',
#  'taxi_119',
#  'taxi_120',
#  'taxi_124',
#  'taxi_125',
#  'taxi_126',
#  'taxi_127',
#  'taxi_128',
#  'taxi_129',
#  'taxi_131',
#  'taxi_136',
#  'taxi_137',
#  'taxi_138',
#  'taxi_140',
#  'taxi_141',
#  'taxi_142',
#  'taxi_143',
#  'taxi_144',
#  'taxi_145',
#  'taxi_146',
#  'taxi_147',
#  'taxi_148',
#  'taxi_151',
#  'taxi_152',
#  'taxi_157',
#  'taxi_158',
#  'taxi_159',
#  'taxi_160',
#  'taxi_161',
#  'taxi_162',
#  'taxi_163',
#  'taxi_164',
#  'taxi_166',
#  'taxi_167',
#  'taxi_168',
#  'taxi_169',
#  'taxi_170',
#  'taxi_171',
#  'taxi_173',
#  'taxi_174',
#  'taxi_179',
#  'taxi_180',
#  'taxi_181',
#  'taxi_182',
#  'taxi_184',
#  'taxi_185',
#  'taxi_186',
#  'taxi_188',
#  'taxi_189',
#  'taxi_194',
#  'taxi_195',
#  'taxi_196',
#  'taxi_198',
#  'taxi_200',
#  'taxi_202',
#  'taxi_205',
#  'taxi_208',
#  'taxi_209',
#  'taxi_211',
#  'taxi_212',
#  'taxi_213',
#  'taxi_215',
#  'taxi_216',
#  'taxi_217',
#  'taxi_220',
#  'taxi_221',
#  'taxi_223',
#  'taxi_224',
#  'taxi_225',
#  'taxi_226',
#  'taxi_228',
#  'taxi_229',
#  'taxi_230',
#  'taxi_231',
#  'taxi_232',
#  'taxi_233',
#  'taxi_234',
#  'taxi_235',
#  'taxi_237',
#  'taxi_238',
#  'taxi_239',
#  'taxi_240',
#  'taxi_241',
#  'taxi_242',
#  'taxi_243',
#  'taxi_244',
#  'taxi_246',
#  'taxi_247',
#  'taxi_248',
#  'taxi_249',
#  'taxi_250',
#  'taxi_254',
#  'taxi_255',
#  'taxi_256',
#  'taxi_258',
#  'taxi_259',
#  'taxi_260',
#  'taxi_261',
#  'taxi_262',
#  'taxi_263',
#  'taxi_264',
#  'taxi_265']
